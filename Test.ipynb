# %%
#import data_analysis.ipynb 
import import_ipynb
from Data_Analysis import *
# Out:
# importing Jupyter notebook from Data_Analysis.ipynb
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
x = [1, 2 , 2.5, 1.8, 1.2, 3.6]
errore_x = [0.5, 1, 0.1, 0.5, 0.4, 0.3]
a = compatibilità_list(x,errore_x)
print(a)
# Out:
# La compatibilità tra l'elemento 1 e 2 è:
# Buona, r = 0.894
# La compatibilità tra l'elemento 1 e 3 è:
# Scarsa r = 2.942
# La compatibilità tra l'elemento 1 e 4 è:
# Sufficiente r = 1.131
# La compatibilità tra l'elemento 1 e 5 è:
# Buona, r = 0.312
# La compatibilità tra l'elemento 1 e 6 è:
# Incompatibilità r = 4.459
# La compatibilità tra l'elemento 2 e 3 è:
# Buona, r = 0.498
# La compatibilità tra l'elemento 2 e 4 è:
# Buona, r = 0.179
# La compatibilità tra l'elemento 2 e 5 è:
# Buona, r = 0.743
# La compatibilità tra l'elemento 2 e 6 è:
# Sufficiente r = 1.533
# La compatibilità tra l'elemento 3 e 4 è:
# Sufficiente r = 1.373
# La compatibilità tra l'elemento 3 e 5 è:
# Incompatibilità r = 3.153
# La compatibilità tra l'elemento 3 e 6 è:
# Incompatibilità r = 3.479
# La compatibilità tra l'elemento 4 e 5 è:
# Buona, r = 0.937
# La compatibilità tra l'elemento 4 e 6 è:
# Incompatibilità r = 3.087
# La compatibilità tra l'elemento 5 e 6 è:
# Incompatibilità r = 4.8

# %%
velocità = [0.12501857418816506, 0.3377796936499026 , 0.9786705738924276 , 5.173305742369384, 5.261613816678994 , 0.1405670474694918, 0.6069139638764814, 10.511562718990888 , 0.22527052576531698,  1.5775275935868251, 2.671602770833734]
#errore_velocità = [0.00006409509095846773, 0.00023353098399002224, 0.00044779853853757436 , 0.020596272008780083, 0.026006174551478824 , 0.00007262138712827439, 0.0005581732544674304 , 0.034082021804363004 , 0.00029703316783571374, 0.0018420509717760717 , 0.015661958100380263]
errore_velocità = [0.000036670628445924206, 0.00010164401284265719, 0.0003669667339277374, 0.02766855314564073,  0.026006174551478824, 0.000014444489758834329, 0.0003406037386506163, 0.034082021804363004, 0.00009246674574684704, 0.0008918906094775717, 0.003744536276137677]
v_inf = [0.13047902831277786, 0.3612326547392903, 1.0924069791328825 , 6.139864188406879 , 6.919876735275608, 0.14707625288413445 , 0.663315298393586, 12.723557449194109 , 0.23840358287407704, 1.7977149912447228, 3.1079169706569005 ]
velocità2 = [0.12501857418816506, 0.3377796936499026 , 0.9786705738924276 , 5.173305742369384, 0.1405670474694918, 0.6069139638764814, 0.22527052576531698,  1.5775275935868251, 2.671602770833734]
#errore_velocità2 = [0.00006409509095846773, 0.00023353098399002224, 0.00044779853853757436 , 0.020596272008780083, 0.00007262138712827439, 0.0005581732544674304 , 0.00029703316783571374, 0.0018420509717760717 , 0.015661958100380263]
errore_velocità2 = [0.000036670628445924206, 0.00010164401284265719, 0.0003669667339277374, 0.02766855314564073, 0.000014444489758834329, 0.0003406037386506163, 0.00009246674574684704, 0.0008918906094775717, 0.003744536276137677]
v_inf2 = [0.13047902831277786, 0.3612326547392903, 1.0924069791328825 , 6.139864188406879 , 0.14707625288413445 , 0.663315298393586, 0.23840358287407704, 1.7977149912447228, 3.1079169706569005 ]
         
diametri = [0.15, 0.2381, 0.3969, 0.635, 0.635, 0.1588, 0.3175, 0.7144, 0.20, 0.4763, 0.5556] #cm
diametri2 = [0.15, 0.2381, 0.3969, 0.635, 0.1588, 0.3175, 0.20, 0.4763, 0.5556] #cm
raggi_quadro = []
raggi_quadro2 = []
for i in range(len(diametri)):
    raggi_quadro.append(pow((diametri[i]/2),2))
for i in range(len(diametri2)):
    raggi_quadro2.append(pow((diametri2[i]/2),2))
print(len(velocità), len(errore_velocità), len(v_inf), len(velocità2), len(errore_velocità2), len(v_inf2))
print(raggi_quadro)
# Out:
# 11 11 11 9 9 9
# [0.005625, 0.0141729025, 0.0393824025, 0.10080625, 0.10080625, 0.00630436, 0.0252015625, 0.12759184, 0.010000000000000002, 0.0567154225, 0.07717283999999999]

# %%
z = interpolazione(velocità2, errore_velocità2, raggi_quadro2, None)
layout = Layout()
traccia1 = traccia(velocità2, errore_velocità2, raggi_quadro2)
retta1 = retta(z[0], z[2], velocità2, errore_velocità2, raggi_quadro2) 
x = [traccia1, retta1]
# Out:
# Il coefficiente angolare 'b' vale:  25.593732037758326
# L'incertezza sul coefficiente angolare vale:  0.00667178220523533
# L'intercetta 'a' della retta vale:  -0.020813709210868187
# L'incertezza sull'intercetta vale:  4.536286603593011e-05
# Inserisci il nome del grafico Prova
# Inserisci il titolo dell'asse y v
# Inserisci l'unità di misura cm/s
# Inserisci il titolo dell'asse x r^2
# Inserisci l'unità di misura cm^2
# Inserisci il mode per la traccia: lines, markers, markers+lines markers
# Inserisci la legenda della traccia v_i
# Scegli di quanto vuoi arrotondare b: 3
# Scegli di quanto vuoi arrotondare a: 2
# Inserisci l'unità di misura della legenda: cm/w

# %%
g = Grafico(x,layout)
# Out:
# <div>
#
#
#             <div id="8523ab7e-e855-4d32-bf49-44d0d18d4bb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8523ab7e-e855-4d32-bf49-44d0d18d4bb9")) {
#                     Plotly.newPlot(
#                         '8523ab7e-e855-4d32-bf49-44d0d18d4bb9',
#                         [{"error_x": {"type": "data"}, "error_y": {"array": [3.6670628445924206e-05, 0.00010164401284265719, 0.0003669667339277374, 0.02766855314564073, 1.4444489758834329e-05, 0.0003406037386506163, 9.246674574684704e-05, 0.0008918906094775717, 0.003744536276137677], "type": "data"}, "mode": "markers", "name": "$v_i$", "showlegend": true, "type": "scatter", "x": [0.005625, 0.0141729025, 0.0393824025, 0.10080625, 0.00630436, 0.0252015625, 0.010000000000000002, 0.0567154225, 0.07717283999999999], "y": [0.12501857418816506, 0.3377796936499026, 0.9786705738924276, 5.173305742369384, 0.1405670474694918, 0.6069139638764814, 0.22527052576531698, 1.5775275935868251, 2.671602770833734]}, {"mode": "lines", "name": "$y = (25.594x-0.02)cm/